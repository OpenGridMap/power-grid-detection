# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), os.pardir))

from training.plot import plot_loss_acc

# %%
figsize = 10, 3

# %%
plot_loss_acc('cnn_140_grey_lr_0.010000_training.log', figsize=figsize)
plot_loss_acc('cnn_140_rgb_lr_0.010000_training.log', figsize=figsize)
