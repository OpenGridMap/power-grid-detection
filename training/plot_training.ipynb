# %%
import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append(os.path.join(os.getcwd(), os.pardir))

from training.plot import plot_loss_acc

# %%
figsize = 10, 3
xlim=None
ylim=None
# xlim=(0., 100.)
# ylim=(0., 1.)
# xlim=(230., 270.)

# %%
plot_loss_acc('cnn_140_1_thr_dil_ero_lr_0.100000_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_grey_lr_0.001000_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.001000_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
plot_loss_acc('cnn_140_grey_lr_0.100000_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.100000_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
# plot_loss_acc('cnn_140_1_thr_dil_ero_lr_0.100000_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_grey_lr_0.100000_2_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.100000_2_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
plot_loss_acc('cnn_140_rgb_lr_0.050000_2_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
plot_loss_acc('cnn_140_grey_lr_0.100000_nesterov_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.100000_nesterov_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_grey_lr_0.070000_nesterov_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
plot_loss_acc('cnn_140_grey_lr_0.035000_nesterov_1_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_grey_lr_0.010000_nesterov_2_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_grey_lr_0.001000_nesterov_3_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
plot_loss_acc('cnn_140_rgb_lr_0.001000_nesterov_r_training.log', figsize=figsize, xlim=xlim, ylim=xlim)

# %%
plot_loss_acc('cnn_140_grey_lr_0.001000_nesterov_r_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.005000_nesterov_r_2_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.005000_nadam_r_2_training.log', figsize=figsize, xlim=xlim, ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.005000_rmsprop_r_2_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
df_rgb = pd.read_csv('cnn_140_rgb_lr_0.001000_nesterov_r_training.log')
df_g = pd.read_csv('cnn_140_grey_lr_0.001000_nesterov_r_training.log')
# df_g = pd.read_csv('cnn_140_rgb_lr_0.005000_nesterov_r_2_training.log')

fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=figsize)

ax1.plot(df_rgb.loss, label='RGB - Training loss', linewidth=1.5)
ax1.plot(df_rgb.val_loss, label='RGB - Validation loss', linewidth=1.5)

ax1.plot(df_g.loss, label='G - Training loss', linewidth=1.5)
ax1.plot(df_g.val_loss, label='G - Validation loss', linewidth=1.5)

# ax1.set_title('Loss vs Epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(loc='upper right')

ax2.plot(df_rgb.acc, label='RGB - Training accuracy', linewidth=1.5)
ax2.plot(df_rgb.val_acc, label='RGB - Validation accuracy', linewidth=1.5)
ax2.plot(df_g.acc, label='G - Training accuracy', linewidth=1.5)
ax2.plot(df_g.val_acc, label='G - Validation accuracy', linewidth=1.5)

ax2.set_xlabel('epochs')
ax2.set_ylabel('binary accuracy')
ax2.legend(loc='upper right')

if xlim is not None:
    ax1.set_xlim(xlim)
    ax2.set_xlim(xlim)

if ylim is not None:
    ax1.set_ylim(ylim)
    ax2.set_ylim(ylim)

plt.show()

# %%
plot_loss_acc('cnn_140_rgb_lr_0.005000_nesterov_r_2_training.log', figsize=figsize, xlim=[0, 70], ylim=ylim)
plot_loss_acc('cnn_140_rgb_lr_0.005000_sgd_he_normal_r_training.log', figsize=figsize, xlim=[0, 70], ylim=ylim)

# %%
df_rgb = pd.read_csv('cnn_140_rgb_lr_0.005000_nesterov_r_2_training.log')
df_g = pd.read_csv('cnn_140_rgb_lr_0.005000_sgd_he_normal_r_training.log')

fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=figsize)

ax1.plot(df_rgb.loss, label='RGB - Training loss', linewidth=1.5)
ax1.plot(df_rgb.val_loss, label='RGB - Validation loss', linewidth=1.5)

ax1.plot(df_g.loss, label='G - Training loss', linewidth=1.5)
ax1.plot(df_g.val_loss, label='G - Validation loss', linewidth=1.5)

# ax1.set_title('Loss vs Epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(loc='upper right')

ax2.plot(df_rgb.acc, label='RGB - Training accuracy', linewidth=1.5)
ax2.plot(df_rgb.val_acc, label='RGB - Validation accuracy', linewidth=1.5)
ax2.plot(df_g.acc, label='G - Training accuracy', linewidth=1.5)
ax2.plot(df_g.val_acc, label='G - Validation accuracy', linewidth=1.5)

ax2.set_xlabel('epochs')
ax2.set_ylabel('binary accuracy')
ax2.legend(loc='upper right')

if xlim is not None:
    ax1.set_xlim(xlim)
    ax2.set_xlim(xlim)

if ylim is not None:
    ax1.set_ylim(ylim)
    ax2.set_ylim(ylim)

plt.show()

# %%
plot_loss_acc('cnn_140_rgb_lr_0.005000_sgd_he_normal_l1_0.010000_l2_0.010000_r_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
df_rgb = pd.read_csv('cnn_140_rgb_lr_0.005000_sgd_he_normal_l1_0.010000_l2_0.010000_r_training.log')

fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=figsize)

ax1.plot(df_rgb.loss, label='RGB - Training loss', linewidth=1.5)
ax2.plot(df_rgb.val_loss, label='RGB - Validation loss', linewidth=1.5)

# ax1.set_title('Loss vs Epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(loc='upper right')

ax2.set_xlabel('epochs')
ax2.set_ylabel('Loss')
ax2.legend(loc='upper right')

ax1.set_ylim([0, 2])

if xlim is not None:
    ax1.set_xlim(xlim)
    ax2.set_xlim(xlim)

if ylim is not None:
    ax1.set_ylim(ylim)
    ax2.set_ylim(ylim)

plt.show()

# %%
plot_loss_acc('cnn_140_rgb_lr_0.005000_sgd_he_normal_l1_0.000010_l2_0.000010_r_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
df_rgb = pd.read_csv('cnn_140_rgb_lr_0.005000_sgd_he_normal_l1_0.000010_l2_0.000010_r_training.log')
df_glorot = pd.read_csv('cnn_140_rgb_lr_0.005000_nesterov_r_2_training.log')
df_g = pd.read_csv('cnn_140_rgb_lr_0.005000_sgd_he_normal_r_training.log')

fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=figsize)

ax1.plot(df_rgb.loss, label='RGB - Training loss', linewidth=1.5)

ax2.plot(df_rgb.val_loss, label='RGB - Validation loss', linewidth=1.5)
ax2.plot(df_g.val_loss, label='No Regularization He - Validation loss', linewidth=1.5)
# ax2.plot(df_glorot.val_loss, label='No Regularization Glorot - Validation loss', linewidth=1.5)

# ax1.set_title('Loss vs Epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(loc='upper right')

ax2.set_xlabel('epochs')
ax2.set_ylabel('Loss')
ax2.legend(loc='upper right')

# ax1.set_ylim([0, 2])
ax2.set_xlim([0, 55])

if xlim is not None:
    ax1.set_xlim(xlim)
    ax2.set_xlim(xlim)

if ylim is not None:
    ax1.set_ylim(ylim)
    ax2.set_ylim(ylim)

plt.show()

# %%
plot_loss_acc('cnn_140_rgb_lr_0.005000_sgd_he_normal__l1_0.000010_l2_0.000010_dropout_0.500000_r_training.log', figsize=figsize, xlim=xlim, ylim=[0, 0.3])
plot_loss_acc('cnn_140_rgb_lr_0.100000_decay_0.001000_sgd_he_normal__l1_0.000010_l2_0.000010_dropout_0.500000_r_training.log', figsize=figsize, xlim=xlim, ylim=ylim)

# %%
df_dropout = pd.read_csv('cnn_140_rgb_lr_0.005000_sgd_he_normal__l1_0.000010_l2_0.000010_dropout_0.500000_r_training.log')
df_decay = pd.read_csv('cnn_140_rgb_lr_0.100000_decay_0.001000_sgd_he_normal__l1_0.000010_l2_0.000010_dropout_0.500000_r_training.log')

fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=figsize)

ax1.plot(df_dropout.val_loss, label='Validation loss 1', linewidth=1.5)
ax1.plot(df_decay.val_loss, label='Validation loss decay', linewidth=1.5)
# ax1.plot(df_dropout.loss, label='Loss 1')
# ax1.plot(df_decay.loss, label='Loss decay')

ax2.plot(df_dropout.acc, label='Accuracy 1', linewidth=1.5)
ax2.plot(df_dropout.val_acc, label='Validation accuracy 1', linewidth=1.5)
ax2.plot(df_decay.acc, label='Accuracy decay', linewidth=1.5)
ax2.plot(df_decay.val_acc, label='Validation accuracy decay', linewidth=1.5)

# ax1.set_title('Loss vs Epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(loc='upper right')

ax2.set_xlabel('epochs')
ax2.set_ylabel('Loss')
ax2.legend(loc='upper right')

# ax1.set_ylim([0, 2])
# ax2.set_xlim([0, 55])

if xlim is not None:
    ax1.set_xlim(xlim)
    ax2.set_xlim(xlim)

if ylim is not None:
    ax1.set_ylim(ylim)
    ax2.set_ylim(ylim)

plt.show()
