# %%
from hdnn_training import train
# Out:
# Using Theano backend.
# Using gpu device 1: GeForce GTX 680 (CNMeM is disabled, cuDNN 5005)

# %%
history = train(None, lr=0.1, n_epochs=500, batch_size=32, input_shape=(140, 140, 1))
# Out:
# loading model...
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 140, 140, 1)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 140, 140, 128) 6400        input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 140, 140, 128) 0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 70, 70, 128)   0           activation_1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
history

# %%
model = history.model

# %%
model

# %%
lr = 0.1
name = 'cnn_140_1_thr_dil_ero_lr_%f_final' % lr

# serialize model to JSON
model_json = model.to_json()

json_file_name = 'results/%s.json' % name

with open(json_file_name, 'wb') as json_file:
    json_file.write(model_json)

weights_file = 'results/%s.h5' % name
    # serialize weights to HDF5
model.save_weights(weights_file)
print("Saved model to disk")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-dd9061a473d4> in <module>()
#      12 weights_file = 'results/%s.h5' % name
#      13     # serialize weights to HDF5
# ---> 14 model.save_weights(weights_file)
#      15 print("Saved model to disk")
#
# /home/tanuj/.tools/anaconda3/envs/py27/lib/python2.7/site-packages/keras/engine/topology.pyc in save_weights(self, filepath, overwrite)
#    2442                 return
#    2443         f = h5py.File(filepath, 'w')
# -> 2444         self.save_weights_to_hdf5_group(f)
#    2445         f.flush()
#    2446         f.close()
#
# /home/tanuj/.tools/anaconda3/envs/py27/lib/python2.7/site-packages/keras/engine/topology.pyc in save_weights_to_hdf5_group(self, f)
#    2458             g = f.create_group(layer.name)
#    2459             symbolic_weights = layer.weights
# ...
